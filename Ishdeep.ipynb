# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishdeep2003/Ishdeep/blob/main/Ishdeep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array([2,3,5,7,8,9,10,15])
y=np.array([10,20,30,40,50,60,70,80])
def Pearson_correlation(x,y):
  if len(x)==len(y):
    Sum_xy=sum((x-x.mean())*(y-y.mean()))
    Sum_x_squared=sum((x-x.mean())**2)
    Sum_y_squared=sum((y-y.mean())**2)
    corr=Sum_xy/np.sqrt(Sum_x_squared*Sum_y_squared)
    return corr

print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
# Out:
# 0.9714106153623109
# 1.0

# %%
print(np.corrcoef(x,y))
# Out:
# [[1.         0.97141062]
#  [0.97141062 1.        ]]

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=load_diabetes(as_frame=True)
df=df.frame
df.head()
# Out:
#         age       sex       bmi        bp        s1  ...        s3        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223  ... -0.043401 -0.002592  0.019907 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449  ...  0.074412 -0.039493 -0.068332 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599  ... -0.032356 -0.002592  0.002861 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  ... -0.036038  0.034309  0.022688 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  ...  0.008142 -0.002592 -0.031988 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
corr=df.corr(method='pearson')
corr
# Out:
#              age       sex       bmi        bp  ...        s4        s5        s6    target
# age     1.000000  0.173737  0.185085  0.335428  ...  0.203841  0.270774  0.301731  0.187889
# sex     0.173737  1.000000  0.088161  0.241010  ...  0.332115  0.149916  0.208133  0.043062
# bmi     0.185085  0.088161  1.000000  0.395411  ...  0.413807  0.446157  0.388680  0.586450
# bp      0.335428  0.241010  0.395411  1.000000  ...  0.257650  0.393480  0.390430  0.441482
# s1      0.260061  0.035277  0.249777  0.242464  ...  0.542207  0.515503  0.325717  0.212022
# s2      0.219243  0.142637  0.261170  0.185548  ...  0.659817  0.318357  0.290600  0.174054
# s3     -0.075181 -0.379090 -0.366811 -0.178762  ... -0.738493 -0.398577 -0.273697 -0.394789
# s4      0.203841  0.332115  0.413807  0.257650  ...  1.000000  0.617859  0.417212  0.430453
# s5      0.270774  0.149916  0.446157  0.393480  ...  0.617859  1.000000  0.464669  0.565883
# ...

# %%
c=np.corrcoef(df['age'],df['sex'])
print('Correlation between age and sex\n',c)
# Out:
# Correlation between age and sex
#  [[1.        0.1737371]
#  [0.1737371 1.       ]]

# %%
plt.figure(figsize=(6,4),dpi=100)
sns.heatmap(corr,annot=True,fmt=".2f", linewidth=.5)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
import yfinance as yf
import seaborn as sns

# %%
start = yf.download('TCS.NS',
                   start='2020-01-01',
                   end='2024-01-01',
                   progress='false')
start
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2020-01-01  1948.982056  1963.637908  1936.753626  1949.341625  1354908
# 2020-01-02  1940.035034  1960.085959  1932.437323  1960.085959  2380752
# 2020-01-03  1978.698242  1998.794169  1945.744751  1945.744751  4655761
# 2020-01-06  1978.518555  2001.446694  1967.234270  1982.609698  3023209
# 2020-01-07  1983.374390  1991.286671  1963.548245  1978.563887  2429317
# ...                 ...          ...          ...          ...      ...
# 2023-12-22  3710.529297  3731.827921  3650.369042  3687.241456  2413058
# 2023-12-26  3682.924072  3720.233092  3677.684165  3706.503062  1285231
# 2023-12-27  3698.109375  3704.901662  3656.191306  3686.271436  1293976
# ...

# %%
import numpy as np
x=np.array(1948.982056,1940.035034)
y=np.array(['Close'])
def Pearson_correlation(Volume,Close):
  if len(Volume)==len(Close):
    Sum_Volume,Close=sum((Volume-Volume.mean())*(Close-Close.mean()))
    Sum_Volume_squared=sum((Volume-Volume.mean())**2)
    Sum_Close_squared=sum((Close-Close.mean())**2)
    corr=Sum_Volume,Close/np.sqrt(Sum_Volume_squared*Sum_Close_squared)
    return corr

print(Pearson_correlation(Volume=Volume,Close=Close))
print(Pearson_correlation(Volume,Volume))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e43fc88f8f80> in <cell line: 0>()
#      10     return corr
#      11
# ---> 12 print(Pearson_correlation(Volume=Volume,Close=Close))
#      13 print(Pearson_correlation(Volume,Volume))
#
# NameError: name 'Volume' is not defined

# %%
start.Close
# Out:
# Ticker           TCS.NS
# Date
# 2020-01-01  1948.982056
# 2020-01-02  1940.035034
# 2020-01-03  1978.698242
# 2020-01-06  1978.518555
# 2020-01-07  1983.374390
# ...                 ...
# 2023-12-22  3710.529297
# 2023-12-26  3682.924072
# 2023-12-27  3698.109375
# 2023-12-28  3687.144531
# 2023-12-29  3680.837646
#
# [992 rows x 1 columns]

# %%
start.Volume
# Out:
# Ticker       TCS.NS
# Date
# 2020-01-01  1354908
# 2020-01-02  2380752
# 2020-01-03  4655761
# 2020-01-06  3023209
# 2020-01-07  2429317
# ...             ...
# 2023-12-22  2413058
# 2023-12-26  1285231
# 2023-12-27  1293976
# 2023-12-28  1682889
# 2023-12-29  1574996
#
# [992 rows x 1 columns]

# %%
df=start[['Close','Volume']]
df
# Out:
# Price             Close   Volume
# Ticker           TCS.NS   TCS.NS
# Date
# 2020-01-01  1948.982056  1354908
# 2020-01-02  1940.035034  2380752
# 2020-01-03  1978.698242  4655761
# 2020-01-06  1978.518555  3023209
# 2020-01-07  1983.374390  2429317
# ...                 ...      ...
# 2023-12-22  3710.529297  2413058
# 2023-12-26  3682.924072  1285231
# 2023-12-27  3698.109375  1293976
# 2023-12-28  3687.144531  1682889
# 2023-12-29  3680.837646  1574996
#
# [992 rows x 2 columns]

# %%
df.corr()
# Out:
# Price             Close    Volume
# Ticker           TCS.NS    TCS.NS
# Price  Ticker
# Close  TCS.NS  1.000000 -0.394147
# Volume TCS.NS -0.394147  1.000000
